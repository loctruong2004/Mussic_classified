# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from youtubesearchpython import VideosSearch
import os
import json
import yt_dlp
from pydub import AudioSegment

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from youtubesearchpython import VideosSearch
import os
import json
import yt_dlp
from pydub import AudioSegment

cid = '56f5940b65e94d7196e42d20756d0ce0' #insert your own id
secret = '922d9068a4c34f4485579d54cdfd7823'

# Kết nối với Spotify API
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=cid,
    client_secret=secret,
))

# Tìm link YouTube dựa trên tên bài hát
def get_youtube_link(song_title, artist_name):
    query = f"{song_title} {artist_name} audio"
    videosSearch = VideosSearch(query, limit=1)
    result = videosSearch.result()
    if result["result"]:
        return result["result"][0]["link"]
    return None

# %%
def get_link(url,save_file_path):
    import time

    playlist_link = f"https://open.spotify.com/playlist/{url}?si=f819917d1bca45b8"
    playlist_id = playlist_link.split("/")[-1].split("?")[0]

    youtube_links = []
    offset = 0
    limit = 100

    while True:
        tracks = sp.playlist_tracks(playlist_id, offset=offset, limit=limit)
        items = tracks['items']
        if not items:
            break  # hết bài

        for item in items:
            track = item['track']
            if not track:
                continue
            name = track['name']
            artist = track['artists'][0]['name']
            yt_link = get_youtube_link(name, artist)
            youtube_links.append((name, artist, yt_link))
            print(f"✅ {name} - {artist} → {yt_link}")
            time.sleep(0.1)  # tránh bị rate limit

        offset += limit

    # Ghi toàn bộ kết quả vào file
    with open(save_file_path, "a", encoding="utf-8") as f:
        for name, artist, link in youtube_links:
            f.write(f"{name} - {artist}: {link}\n")
  

# count mussic in file txt 
def count_lines(file_path):
      # file_path = "/content/drive/MyDrive/api Spotify/youtube_links_bolero.txt"  
      with open(file_path, 'r', encoding='utf-8') as f:
          line_count = sum(1 for _ in f)

      print(f"📄 Số dòng trong file '{file_path}': {line_count}")


# clean duplicate and rm remix 
def clean_data(input_file):
    seen_links = set()
    cleaned_lines = []

    with open(input_file, "r", encoding="utf-8") as f:
        for line in f:
            line_lower = line.lower()
            if "remix" in line_lower or "Remix" in line_lower:
                continue  

            if ':' not in line:
                continue  # bỏ dòng sai định dạng

            try:
                _, link = line.strip().split(':', 1)
                link = link.strip()

                if link in seen_links:
                    continue  # bỏ dòng nếu link đã xuất hiện

                seen_links.add(link)
                cleaned_lines.append(line.strip())
            except Exception as e:
                print(f"⚠️ Lỗi xử lý dòng: {line.strip()}")

    # Ghi lại kết quả đã lọc
    with open(input_file, "w", encoding="utf-8") as f:
        for line in cleaned_lines:
            f.write(line + "\n")

    print(f"Đã lưu {len(cleaned_lines)} dòng sạch vào: {input_file}")

# %%
# Mở và đọc file
links = []

with open('D:\classified_music\link.txt', 'r', encoding='utf-8') as file:
    for line in file:
        line = line.strip()
        if 'https://www.youtube.com/watch?' in line:
            # Tách và lấy phần URL
            parts = line.split('https://www.youtube.com/watch?')
            link = 'https://www.youtube.com/watch?' + parts[1]
            links.append(link)

# In ra kết quả
print(links)
# Out:
# ['https://www.youtube.com/watch?v=KHhyUgqMwDg', 'https://www.youtube.com/watch?v=2AocZ9QoqiE', 'https://www.youtube.com/watch?v=f74UkXWQg1M', 'https://www.youtube.com/watch?v=MQwlWpdAiOM', 'https://www.youtube.com/watch?v=vjxkAEnweSo', 'https://www.youtube.com/watch?v=lAotY-cyYVI', 'https://www.youtube.com/watch?v=-GTJ65WLNKM', 'https://www.youtube.com/watch?v=qMNmgkJ7WiY', 'https://www.youtube.com/watch?v=QgmH7LAJtqU', 'https://www.youtube.com/watch?v=miR5Ld3NVQc', 'https://www.youtube.com/watch?v=I2H2iWUbygY', 'https://www.youtube.com/watch?v=q6s-7WGUC-c', 'https://www.youtube.com/watch?v=CiHVVcNdQTk', 'https://www.youtube.com/watch?v=IF8RG3bmfxU', 'https://www.youtube.com/watch?v=_-7AveMHHOs', 'https://www.youtube.com/watch?v=ATm5CGT8qfw', 'https://www.youtube.com/watch?v=iYJ9Q3Iw_Ao', 'https://www.youtube.com/watch?v=5wtu-Qwk3dA', 'https://www.youtube.com/watch?v=sxVx0SgNAAQ', 'https://www.youtube.com/watch?v=lC3ETcy4gDs', 'https://www.youtube.com/watch?v=Z56vM5pgnPU', 'https://w
# ...

# %%
get_link("3InDCr5XeNRo5Ml3rbPbxu","link.txt")
# Out:
# ✅ Con Cò Bé Bé - Bé Bào Ngư → https://www.youtube.com/watch?v=tKUVfqZq6fA
# ✅ Bà Còng Đi Chợ - Bao An → https://www.youtube.com/watch?v=_jUfRtx0eNk
# ✅ Rửa Mặt Như Mèo - Mầm Chồi Lá → https://www.youtube.com/watch?v=oFGz1kcRPfY
# ✅ Ngày Đầu Tiên Đi Học - Xuân Mai → https://www.youtube.com/watch?v=jkHnCBL_0hU
# ✅ Con Heo Đất - Phuong Thao → https://www.youtube.com/watch?v=KtQsDqHEIXo
# ✅ Bắc Kim Thang - Bao An → https://www.youtube.com/watch?v=1OH-lzuwcmM
# ✅ Quả Gì - Bao An → https://www.youtube.com/watch?v=-nK9e4N9kg4
# ✅ Cả Nhà Thương Nhau - Bao An → https://www.youtube.com/watch?v=1C_rM7TIS9M
# ✅ Đàn Gà Trong Sân - Mầm Chồi Lá → https://www.youtube.com/watch?v=BhMncz0ERkI
# ✅ Hỏng Dám Đâu - Mầm Chồi Lá → https://www.youtube.com/watch?v=snc_a4Hs9Lo
# ✅ Bố Là Tất Cả - Mầm Chồi Lá → https://www.youtube.com/watch?v=iYJ9Q3Iw_Ao
# ✅ Cháu Vẽ Ông Mặt Trời - Mầm Chồi Lá → https://www.youtube.com/watch?v=hiKF_5ACPsw
# ...

# %%
import os

def count_wav_files(folder_path):
    count = 0
    for file in os.listdir(folder_path):
        if file.lower().endswith('.wav'):
            count += 1
    return count

# Ví dụ sử dụng
folder = '/duong/dan/den/folder'  # thay bằng đường dẫn thật của bạn
num_wav_files = count_wav_files(folder)
print(f"Số lượng file .wav trong thư mục: {num_wav_files}")

# %%
import os

def count_wav_files(folder_path):
    count = 0
    for file in os.listdir(folder_path):
        if file.lower().endswith('.png'):
            count += 1
    return count

# Ví dụ sử dụng
folder_bolero = r'D:\classified_music\dataset\train\bolero'  
folder_cailuong = r'D:\classified_music\dataset\train\cailuong'  
folder_cheo = r'D:\classified_music\dataset\train\cheo'  
folder_danca = r'D:\classified_music\dataset\train\danca'  
folder_nhacdo = r'D:\classified_music\dataset\train\nhacdo'  
folder_nhacxuan = r'D:\classified_music\dataset\train\thieunhi'  
folder_pop = r'D:\classified_music\dataset\train\pop'  
num_folder_bolero = count_wav_files(folder_bolero)
num_folder_cailuong = count_wav_files(folder_cailuong)
num_folder_cheo = count_wav_files(folder_cheo)
num_folder_danca = count_wav_files(folder_danca)
num_folder_nhacdo = count_wav_files(folder_nhacdo)
num_folder_nhacxuan = count_wav_files(folder_nhacxuan)
# num_folder_pop = count_wav_files(folder_pop)
print(f"{folder_bolero}: {num_folder_bolero}")
print(f"{folder_cailuong}: {num_folder_cailuong}")
print(f"{folder_cheo}: {num_folder_cheo}")
print(f"{folder_danca}: {num_folder_danca}")
print(f"{folder_nhacdo}: {num_folder_nhacdo}")
print(f"{folder_nhacxuan}: {num_folder_nhacxuan}")
print(f"{folder_pop}: {num_folder_pop}")

# %%
import os
import shutil

# Đường dẫn thư mục nguồn và đích
src_folder = r"D:\classified_music\data\nhac do"
dst_folder = r"D:\classified_music\data\nhacdo"

# Tạo thư mục đích nếu chưa tồn tại
os.makedirs(dst_folder, exist_ok=True)

# Duyệt tất cả các file trong thư mục nguồn
for filename in os.listdir(src_folder):
    if filename.lower().endswith(".png"):
        src_path = os.path.join(src_folder, filename)
        dst_path = os.path.join(dst_folder, filename)
        
        # Di chuyển file
        shutil.move(src_path, dst_path)
        print(f"Đã di chuyển: {filename}")

# %%
import os
def count_wav_files(folder_path):
    count = 0
    for file in os.listdir(folder_path):
        if file.lower().endswith('.png'):
            count += 1
    return count
folder_add = r"D:\classified_music\data\dataset2\cheo"
folder_add_remix = r"D:\classified_music\data\dataset2\remix"
folder_add_thieunhi = r"D:\classified_music\data\dataset2\thieunhi"

num_add = count_wav_files(folder_add)
print(f"{folder_add}: {num_add}")
num_add_remix = count_wav_files(folder_add_remix)
print(f"{folder_add_remix}: {num_add_remix}")
num_add_thieunhi = count_wav_files(folder_add_thieunhi)
print(f"{folder_add_thieunhi}: {num_add_thieunhi}")
# Out:
# D:\classified_music\data\dataset2\cheo: 3165
# D:\classified_music\data\dataset2\remix: 2985
# D:\classified_music\data\dataset2\thieunhi: 2820

# %%
import time,random

def download_and_convert_youtube(link, save_path_wav):
    temp_file = save_path_wav.replace('.wav', '')

    ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': temp_file,
    'quiet': True,
    'cookiefile': 'cookie.txt' # file content cookie youtube
    }
    ydl_opts_info = {
        'quiet': True,
        'skip_download': True,
        'cookiefile': 'cookie.txt'
    }
    try:
        with yt_dlp.YoutubeDL(ydl_opts_info) as ydl:
            info = ydl.extract_info(link, download=False)
            # duration = info.get("duration", 0)

            # if duration > 600:
            #     print(f"video dài hơn 10 phút: {link} ({duration // 60} phút)")
            #     return
        # dowload wav
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            print(f"🎵 Đang tải: {link}")
            ydl.download([link])
            time.sleep(random.uniform(5, 15))
        if not os.path.exists(temp_file):
            raise FileNotFoundError(f" Không tìm thấy file tạm: {temp_file}")

        audio = AudioSegment.from_file(temp_file)
        audio = audio.set_channels(1).set_frame_rate(16000)
        audio.export(save_path_wav, format="wav")
        os.remove(temp_file)
        print(f" Đã lưu: {save_path_wav}")
    except Exception as e:
        print(f" Lỗi với {link}: {e}")

# %%
import subprocess

def download_and_convert_youtube_ffmpeg(link, save_path_wav):
    temp_file = save_path_wav.replace('.wav', '.m4a')

    ydl_opts = {
        'format': 'bestaudio[ext=m4a]/bestaudio/best',
        'outtmpl': temp_file,
        'quiet': True,
        'cookiefile': 'cookie.txt'
    }

    try:
        # Download audio
        print(f"🎵 Đang tải: {link}")
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([link])
        
        if not os.path.exists(temp_file):
            raise FileNotFoundError(f"Không tìm thấy file: {temp_file}")

        # Convert bằng ffmpeg
        print(f"🎧 Đang chuyển đổi sang WAV...")
        cmd = [
            "ffmpeg", "-y",
            "-i", temp_file,
            "-ac", "1",               # mono
            "-ar", "16000",           # sample rate 16kHz
            save_path_wav
        ]
        subprocess.run(cmd, check=True)

        os.remove(temp_file)
        print(f"✅ Đã lưu WAV: {save_path_wav}")
    except Exception as e:
        print(f"❌ Lỗi với {link}: {e}")

# %%
download_and_convert_youtube_ffmpeg("https://youtu.be/wtbRapiOBrI?si=b6jTYFNJ_TIHxB6P",r"D:\classified_music\data_test\remix\remix5.wav")
# Out:
# 🎵 Đang tải: https://youtu.be/wtbRapiOBrI?si=b6jTYFNJ_TIHxB6P
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: D:\classified_music\data_test\remix\remix5.wav

# %%
print(links)
# Out:
# ['https://www.youtube.com/watch?v=KHhyUgqMwDg', 'https://www.youtube.com/watch?v=2AocZ9QoqiE', 'https://www.youtube.com/watch?v=f74UkXWQg1M', 'https://www.youtube.com/watch?v=MQwlWpdAiOM', 'https://www.youtube.com/watch?v=vjxkAEnweSo', 'https://www.youtube.com/watch?v=lAotY-cyYVI', 'https://www.youtube.com/watch?v=-GTJ65WLNKM', 'https://www.youtube.com/watch?v=qMNmgkJ7WiY', 'https://www.youtube.com/watch?v=QgmH7LAJtqU', 'https://www.youtube.com/watch?v=miR5Ld3NVQc', 'https://www.youtube.com/watch?v=I2H2iWUbygY', 'https://www.youtube.com/watch?v=q6s-7WGUC-c', 'https://www.youtube.com/watch?v=CiHVVcNdQTk', 'https://www.youtube.com/watch?v=IF8RG3bmfxU', 'https://www.youtube.com/watch?v=_-7AveMHHOs', 'https://www.youtube.com/watch?v=ATm5CGT8qfw', 'https://www.youtube.com/watch?v=iYJ9Q3Iw_Ao', 'https://www.youtube.com/watch?v=5wtu-Qwk3dA', 'https://www.youtube.com/watch?v=sxVx0SgNAAQ', 'https://www.youtube.com/watch?v=lC3ETcy4gDs', 'https://www.youtube.com/watch?v=Z56vM5pgnPU', 'https://w
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/cheo/cheo_39.wav
# 🎵 Đang tải: https://youtu.be/6mhYvZN_oO0?si=Db6kbx2_w0DDZF6K
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/cheo/cheo_40.wav
# 🎵 Đang tải: https://youtu.be/lJUo0BlB4yE?si=y-ZGWjwURyDfucp9
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/cheo/cheo_41.wav
# 🎵 Đang tải: https://youtu.be/ULLHR7y5nXQ?si=ClR7DZcFhax5awJ2
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/cheo/cheo_42.wav
# 🎵 Đang tải: https://youtu.be/o8iP3EYf83M?si=mGK4mLLQtzGfrBoF
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/cheo/cheo_43.wav
# 🎵 Đang tải: https://youtu.be/YSNsQefDt2o?si=b5VBOiYizwgBskzu
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/cheo/cheo_44.wav

# %%
download_and_convert_youtube_ffmpeg("https://youtu.be/BWk_UdqQb9g?si=7HGqsnwvJOu3my8z",r"D:\classified_music\data_test\remix_test.wav")
# Out:
# 🎵 Đang tải: https://youtu.be/BWk_UdqQb9g?si=7HGqsnwvJOu3my8z
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: D:\classified_music\data_test\remix_test.wav

# %%
const links = new Set();

[...document.querySelectorAll('a.yt-simple-endpoint')].forEach(a => {
    const href = a.getAttribute('href');
    if (href && href.includes('/watch?v=')) {
        links.add('https://www.youtube.com' + href.split('&')[0]); // loại bỏ các tham số sau & nếu có
    }
});

const arr = [...links].slice(0, 15);
console.log(arr);

# %%
list_cheo = ["https://youtu.be/0r1iZc8rqFI?si=WuweqsRQ8UVvlr9A",
              "https://youtu.be/Re8VvXUoZUY?si=knLxt-3EBtPgeynv",
              "https://youtu.be/b0Lfw10UYys?si=LgUaINHo-22LJwDB",
              "https://youtu.be/sBY0vTvonoc?si=cM5Aa2vQPaGM2ZKp",
              "https://youtu.be/bTsbtCahXpg?si=dBr-8KbBhnQjlgih",
              "https://youtu.be/MCUqqtSOsc8?si=OPhtTV8rYwwaiZia",
              "https://youtu.be/btg28zENotY?si=hkualSPx6xNP8w_T",
              "https://youtu.be/5avHxv5TzCM?si=tTpUT2TzW3tSmAvY",
              "https://youtu.be/0OXT8-5rRyc?si=IuC__I5tN-7M8Jka",
              "https://youtu.be/valZUXGk-Tw?si=BcfpdQs-mIhi-z_G"
              ]

# %%
index = 0
for i in list_cheo:
    index +=1
    download_and_convert_youtube_ffmpeg(i,f"./data/cheo/cheo_{index}.wav")

# %%
list_remix = [ "https://youtu.be/HYzJrUvDAbg?si=J4D9i9qa1womN70y",
               "https://youtu.be/sqaXjzBfrCY?si=l8wQGhjU32kP0kb8",
               "https://youtu.be/aVZUmJskmrc?si=WlqlenBS1KsN-jpO",
               "https://youtu.be/l2cQFJy-Wx8?si=IaMXO0mzzd5ggSeh",
               "https://youtu.be/1H3_w5_PDQA?si=0FKo11FV488k9fRH",
               "https://youtu.be/1v_ZXMpGf3U?si=4Z-3cf-mLdHExki3",
               "https://youtu.be/RJDB4EaFFRI?si=zu9O_1Q5EhHPb0p6",
               "https://youtu.be/RJDB4EaFFRI?si=v_avhsAlDw2GDY3H",
         'https://www.youtube.com/watch?v=r7Hqyox_yEY',
         'https://www.youtube.com/watch?v=0HWMaUHk3d4',
         'https://www.youtube.com/watch?v=83XSDal3KKw',
         'https://www.youtube.com/watch?v=E-2j-0a4rSs',
         'https://www.youtube.com/watch?v=kVuXl9UbCX4',
         'https://www.youtube.com/watch?v=Y9TRj4HPoo4',
         'https://www.youtube.com/watch?v=wt0k2Dn_4oE',
         'https://www.youtube.com/watch?v=Xk8aDlC2nIM',
         'https://www.youtube.com/watch?v=7ovh5bVQSWE',
         'https://www.youtube.com/watch?v=EtOnkYp0rE8',
         'https://www.youtube.com/watch?v=YbLEl4PFyPM',
         'https://www.youtube.com/watch?v=nmlFrKJLwW0',
         'https://www.youtube.com/watch?v=Xp6_cWO2in0',
         'https://www.youtube.com/watch?v=T_61bDvM4YI',
         'https://www.youtube.com/watch?v=TKt4OtgLby8',
         'https://www.youtube.com/watch?v=FRxaSyhKWmc',
         'https://www.youtube.com/watch?v=WxL-vS2LypY',
         'https://www.youtube.com/watch?v=MJbpt1nPku8',
         'https://www.youtube.com/watch?v=GZhVssGYx8U',
         'https://www.youtube.com/watch?v=Q7PkmLTlVdU',
         'https://www.youtube.com/watch?v=3xLY9Fa4Rus',
         'https://www.youtube.com/watch?v=dX5ZIuRjF1Q',
         'https://www.youtube.com/watch?v=eXxCihBmaCA',
         'https://www.youtube.com/watch?v=6jz5-4Fv510',
         'https://www.youtube.com/watch?v=BAl1VQur4uI']
index = 0
for i in remix:
    index +=1
    download_and_convert_youtube_ffmpeg(i,f"./data/remix/remix_{index}.wav")
# Out:
# 🎵 Đang tải: https://www.youtube.com/watch?v=E-2j-0a4rSs
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_1.wav
# 🎵 Đang tải: https://www.youtube.com/watch?v=QLJLZZgHTGo
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_2.wav
# 🎵 Đang tải: https://www.youtube.com/watch?v=Xk8aDlC2nIM
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_3.wav
# 🎵 Đang tải: https://www.youtube.com/watch?v=q0tvU2MFyVA
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_4.wav
# 🎵 Đang tải: https://www.youtube.com/watch?v=OPBd86A1Rfo
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_5.wav
# 🎵 Đang tải: https://www.youtube.com/watch?v=9QuBiVbio-Y
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_6.wav
# 🎵 Đang tải: https://www.youtube.com/watch?v=KRGsIspC-aw
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_7.wav
# 🎵 Đang tải: https://www.youtube.com/watch?v=wt0k2Dn_4oE
# ...

# %%
remix = ["https://youtu.be/VWzfXaa4XEs?si=npxkLvGJ0PXRbcxm",
         "https://youtu.be/rKzJx7RNqaQ?si=vnlP6CP5_i8AYYFs",
         "https://youtu.be/z59N_J2XywA?si=JTTT_HvhVyQntkU-",
         "https://youtu.be/ZlaGQu7Jgsg?si=q79p521RFH5GSefg",
         "https://www.youtube.com/live/wTy-UFtBKrY?si=5x7pmNtvdMqvXdwp",
         "https://youtu.be/bjgGr3xs_tA?si=KJuvzpUJ4RWJsQrN"
         ]
index = 43
for i in remix:
    index +=1
    download_and_convert_youtube_ffmpeg(i,f"./data/remix/remix_{index}.wav")
# Out:
# 🎵 Đang tải: https://youtu.be/VWzfXaa4XEs?si=npxkLvGJ0PXRbcxm
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_44.wav
# 🎵 Đang tải: https://youtu.be/rKzJx7RNqaQ?si=vnlP6CP5_i8AYYFs
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_45.wav
# 🎵 Đang tải: https://youtu.be/z59N_J2XywA?si=JTTT_HvhVyQntkU-
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_46.wav
# 🎵 Đang tải: https://youtu.be/ZlaGQu7Jgsg?si=q79p521RFH5GSefg
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_47.wav
# 🎵 Đang tải: https://www.youtube.com/live/wTy-UFtBKrY?si=5x7pmNtvdMqvXdwp
# [download]  78.1% of ~ 115.43MiB at  441.53KiB/s ETA 00:58 (frag 1155/1477)
# [download] Got error: HTTPSConnectionPool(host='rr7---sn-8qj-i5ol7.googlevideo.com', port=443): Read timed out. (read timeout=20.0)
# 🎧 Đang chuyển đổi sang WAV...
# ✅ Đã lưu WAV: ./data/remix/remix_48.wav
# 🎵 Đang tải: https://youtu.be/bjgGr3xs_tA?si=KJuvzpUJ4RWJsQrN
# ...

# %%
download_and_convert_youtube_ffmpeg("https://youtu.be/UjyJu6NxyQU?si=i7IyIFhvfMDIVnPc",r"D:\classified_music\data\add\cheo\cheo_add_1.wav")

# %%
from youtubesearchpython import VideosSearch

keywords = ["nonstop remix", "rap viet", "nhac rock", "nhac chill", "usuk 2024"]
video_links = []

for kw in keywords:
    results = VideosSearch(kw, limit=4).result()  # lấy nhiều hơn để loại được live
    for video in results['result']:
        # Bỏ video live stream
        if video['duration'] is None:
            continue
        link = video['link']
        video_links.append(link)

# In danh sách link sạch
for link in video_links:
    print(link)

# %%
index = 3
for i in video_links:
    index +=1
    download_and_convert_youtube_ffmpeg(i,f"./add_dataset/other/other_add_{index}.wav")

# %%
download_and_convert_youtube("https://youtu.be/ksw7MKUXhco?si=6oHDfDVN-KJkcJd_",R"D:\classified_music\add_dataset\bolero\boleroadd3.wav")

# %%
download_and_convert_youtube("https://youtu.be/dNO9oXUFBTM?si=YfbGfh5HB_iXGF9t",R"D:\classified_music\add_dataset\bolero\boleroadd4.wav")

# %%
download_and_convert_youtube("https://youtu.be/ndLsUTEFlT0?si=HD2wdQlskb_0F41R",R"D:\classified_music\add_dataset\bolero\boleroadd5.wav")

# %%
download_and_convert_youtube("https://youtu.be/L21bQFJ2_mY?si=Ypu8r2EbKh8YM3fn",R"D:\classified_music\add_dataset\bolero\boleroadd6.wav")

# %%
download_and_convert_youtube("https://youtu.be/vqeo9ZmKZew?si=ILsocvr21zkjtfmt",R"D:\classified_music\add_dataset\bolero\boleroadd7.wav")

# %%
download_and_convert_youtube("https://youtu.be/eXmtLHF-BTI?si=qdzoK7p-jZwm4pFY",R"D:\classified_music\add_dataset\bolero\boleroadd8.wav")

# %%
download_and_convert_youtube("https://youtu.be/09ChKJM-t74?si=L_w-x3H_jo7XGWT9",R"D:\classified_music\add_dataset\bolero\boleroadd9.wav")
